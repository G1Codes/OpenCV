# %% [markdown]
# # Face & Object Detection

# %%
import cv2

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Read image
img = cv2.imread("face1.jpg")
if img is None:
    print("Error: Could not load image. Please check the file path and format.")
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# Draw boxes
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow("Faces", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv2

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Read image
img = cv2.imread(r"c:\Users\Jivan.Patil\Downloads\multi_faces.jpg")

if img is None:
    print("Error: Could not load image. Please check the file path and format.")
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# Draw boxes
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow("Faces", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cv2.data.haarcascades
# Out:
# 'd:\\RAG\\rag_env\\Lib\\site-packages\\cv2\\data\\'

# %% [markdown]
# ## Webcam

# %%
import cv2

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read() #retrn = True/False, frame= Image
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    # Draw boxes
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    cv2.imshow("Webcam", frame)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

cap.release()

cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Eye & Smile detection

# %%
import cv2

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")
smile_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_smile.xml")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

        # Draw boxes
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]

    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 10)
    if len(eyes)>0:
        cv2.putText(frame, "Eyes Detected", (x,y-30), cv2.FONT_HERSHEY_COMPLEX, 0.6, (0,0,255), 2)

    smiles = smile_cascade.detectMultiScale(roi_gray, 1.7, 20)
    if len(smiles)>0:
        cv2.putText(frame, "Smile Detected", (x,y-10), cv2.FONT_HERSHEY_COMPLEX, 0.6, (0,50,180), 2)

    cv2.imshow("Webcam Face Detector", frame)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

cap.release()

cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
